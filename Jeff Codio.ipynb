# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jeff Codio**

# %% [markdown]
# *I am interested in Data Science because I love gathering information.*

# %% [markdown]
# ### The codio in Cell 5 will subtract two numbers from each other

# %%
2-2
# Out:
# 0

# %% [markdown]
# <blockquote>I'm learning so much</blockquote>
# <hr>
# <ol>
# <li>Coding</li>
# <li>Gathering Data</li>
# <li>Applying the new Skills</li>
# </ol>
